# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # data science

# %% [markdown]
# #

# %%
df = pd.read_csv('Salary_Data.csv')
df.head()
# Out:
#     Age  Gender EducationLevel          Job Title  YearsofExperience    Salary
# 0  32.0    Male     Bachelor's  Software Engineer                5.0   90000.0
# 1  28.0  Female       Master's       Data Analyst                3.0   65000.0
# 2  45.0    Male            PhD     Senior Manager               15.0  150000.0
# 3  36.0  Female     Bachelor's    Sales Associate                7.0   60000.0
# 4  52.0    Male       Master's           Director               20.0  200000.0

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='Age',y='Salary',data = df, hue = 'YearsofExperience',alpha = 0.6)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(x='Age',y='Salary',data = df, style = 'Salary')
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
df1 = pd.read_csv('Fs.csv')
df1
# Out:
#                                      FILM  STARS  RATING  VOTES
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                   Jurassic World (2015)    4.5     4.5  34390
# 2                  American Sniper (2015)    5.0     4.8  34085
# 3                        Furious 7 (2015)    5.0     4.8  33538
# 4                       Inside Out (2015)    4.5     4.5  15749
# ..                                    ...    ...     ...    ...
# 505                      Valiyavan (2015)    0.0     0.0      0
# 506            WWE SummerSlam 2015 (2015)    0.0     0.0      0
# 507       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0
# 508  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0
# 509                            Zarafa (1)    0.0     0.0      0
#
# [510 rows x 4 columns]

# %%
sns.scatterplot(y='VOTES',x ='RATING',data = df1)
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %%
sns.scatterplot(x='VOTES',y ='RATING',data = df1, hue= 'STARS')
# Out:
# <Axes: xlabel='VOTES', ylabel='RATING'>

# %%
sns.boxplot(x='VOTES',y ='RATING',data = df1)
# Out:
# <Axes: xlabel='VOTES', ylabel='RATING'>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    510 non-null    object
#  1   STARS   510 non-null    float64
#  2   RATING  510 non-null    float64
#  3   VOTES   510 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 16.1+ KB

# %%
df1.describe()       #statistical information
# Out:
#             STARS      RATING         VOTES
# count  510.000000  510.000000    510.000000
# mean     3.532353    3.351765   1134.364706
# std      1.585616    1.512628   3809.952176
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.025000      2.000000
# 50%      4.000000    3.800000     17.500000
# 75%      4.500000    4.300000    183.500000
# max      5.000000    5.000000  34846.000000

# %%
df1['RATING']
# Out:
# 0      3.9
# 1      4.5
# 2      4.8
# 3      4.8
# 4      4.5
#       ...
# 505    0.0
# 506    0.0
# 507    0.0
# 508    0.0
# 509    0.0
# Name: RATING, Length: 510, dtype: float64

# %%
plt.plot(df1['FILM'].head(3),df1['RATING'].head(3),marker='o')

# %%
sns.scatterplot(data = df1.head(10), x='FILM',y = 'RATING', hue = 'VOTES')
# Out:
# <Axes: xlabel='FILM', ylabel='RATING'>

# %%
sns.regplot(data = df1, x='STARS',y = 'RATING')
# Out:
# <Axes: xlabel='STARS', ylabel='RATING'>

# %%
data1 = pd.read_csv('mcu_box_office.csv')
print(data1)
# Out:
#                                   movie_title  mcu_phase release_date  \
# 0                                    Iron Man          1     5/2/2008
# 1                         The Incredible Hulk          1    6/13/2008
# 2                                  Iron Man 2          1     5/7/2010
# 3                                        Thor          1     5/6/2011
# 4          Captain America: The First Avenger          1    7/22/2011
# 5                                The Avengers          1     5/4/2012
# 6                                  Iron Man 3          2     5/3/2013
# 7                        Thor: The Dark World          2    11/8/2013
# 8         Captain America: The Winter Soldier          2     4/4/2014
# 9                     Guardians of the Galaxy          2     8/1/2014
# 10                    Avengers: Age of Ultron          2     5/1/2015
# 11                                    Ant-Man          2    7/17/2015
# ...

# %%
data1.columns
# Out:
# Index(['movie_title', 'mcu_phase', 'release_date', 'tomato_meter',
#        'audience_score', 'movie_duration', 'production_budget',
#        'opening_weekend', 'domestic_box_office', 'worldwide_box_office'],
#       dtype='object')

# %%
data_7 = data1.drop(columns=['mcu_phase','tomato_meter','movie_duration','release_date','audience_score',

'domestic_box_office', 'worldwide_box_office'])
print(data_7)
# Out:
#                                   movie_title production_budget  \
# 0                                    Iron Man       186,000,000
# 1                         The Incredible Hulk       137,500,000
# 2                                  Iron Man 2       170,000,000
# 3                                        Thor       150,000,000
# 4          Captain America: The First Avenger       140,000,000
# 5                                The Avengers       225,000,000
# 6                                  Iron Man 3       200,000,000
# 7                        Thor: The Dark World       150,000,000
# 8         Captain America: The Winter Soldier       170,000,000
# 9                     Guardians of the Galaxy       170,000,000
# 10                    Avengers: Age of Ultron       365,000,000
# 11                                    Ant-Man       130,000,000
# 12                 Captain America: Civil War       250,000,000
# 13                             Doctor Strange       165,000,000
# ...

# %%
sns.histplot(data=data1['tomato_meter'],kde=True)
# Out:
# <Axes: xlabel='tomato_meter', ylabel='Count'>

# %%
plt.pie(data1['tomato_meter'].head(5))
# Out:
# ([<matplotlib.patches.Wedge at 0x2428a318790>,
# ...
#  [Text(0.7979627596468291, 0.7571363379318264, ''),
#   Text(-0.5163315736629176, 0.9712886831621047, ''),
#   Text(-1.0991033056577928, -0.04440634517850722, ''),
#   Text(-0.3534081240569828, -1.0416826281792955, ''),
#   Text(0.8836109783804981, -0.6551577206180655, '')])
